# %%
import csv
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
# Load CSV file
df = pd.read_csv("transition_parameters.csv")
df.sample(5)

# Replace multiple column names using a dictionary
db=pd.read_csv('Critical_Reynolds_Mach4.5(all).csv')
db.sample(10)
# Out:
#     Pressure_Pa  Re_cr_Pressure  Temperature_K  Re_cr_Temperature  \
# 96  4863.636364     396896.4596     586.363636        223561.9814
# 17  1272.727273     303551.2850     227.272727        297087.1462
# 40  2318.181818     342227.1847     331.818182        265202.7390
# 13  1090.909091     294335.5487     209.090909        304612.3546
# 79  4090.909091     383397.2304     509.090909        233243.4499
# 98  4954.545455     398369.2142     595.454545        222532.5141
# 73  3818.181818     378143.2274     481.818182        237128.1448
# 64  3409.090909     369668.7356     440.909091        243524.8828
# 38  2227.272727     339499.9271     322.727273        267422.1392
# 3    636.363636     264256.7421     163.636364        327856.7376
#
#     Compressibility_Z  Re_cr_Compressibility  WallTemp_K  Re_cr_WallTemp  \
# 96           1.187879            252551.0204  778.787879     180935.0287
# 17           0.868687            345348.8372  220.202020     299889.8779
# ...

# %%
df.rename(columns={
    "TurbulenceIntensity(%)":"Turbulence Intensity(%)",
    "Re_theta_Tu":"Critical Reynolds Number at Beginning",
    "Roughness_k+":"Surface Roughness of the Object",
    "MachNumber":"Mach Number",
    "Re_theta_M":"",
    "PressureGradient_lambda":"",
    "Re_theta_lambda":""
    
}, inplace=True)

df.to_csv("SubSonic.csv", index=False)

print("Column names updated successfully!")
# Out:
# Column names updated successfully!

# %%
dk=pd.read_csv("data_renamed.csv")
dk.sample(10)
# Out:
#    Altitude  V(infinity)  Mach Number  Nose Radius  Degree  \
# 5     22.86         5.94        19.89        3.556   0.425
# 1     30.48         6.02        19.79        3.099   0.000
# 4     24.38         5.97        19.97        3.429   0.140
# 7     19.81         5.86        19.97        3.835   0.715
# 3     25.91         5.99        20.03        3.327   0.000
# 9     18.29         5.80        19.95        3.988   1.550
# 2     27.43         6.00        20.07        3.251   0.000
# 0     36.58         6.03        19.25        2.896   0.000
# 8     18.29         5.80        19.95        3.988   0.750
# 6     21.34         5.90        19.95        3.683   0.660
#
#    Effective Cone Angle  Transition Start Location along the body  \
# 5                 4.575                                     1.402
# 1                 5.000                                     2.908
# 4                 4.860                                     1.986
# ...
